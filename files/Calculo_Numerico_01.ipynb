# %% [markdown]
# # Artimética de Ponto Flutuante

# %% [markdown]
# ### Soma em 8 bits

# %%
Int8(100) + Int8(27)+Int8(1)
# Out:
# -128

# %% [markdown]
# ### Usando a precisão total da máquina (64 bits)

# %%
x = 2^63 - 1
# Out:
# 9223372036854775807

# %%
x+1
# Out:
# -9223372036854775808

# %%
-(x+1)
# Out:
# -9223372036854775808

# %%
y = 2^62
# Out:
# 4611686018427387904

# %%
y^2
# Out:
# 0

# %%
x * y
# Out:
# -4611686018427387904

# %% [markdown]
# ## O tipo "BigInt"

# %%
(BigInt(2)^64)^10
# Out:
# 4562440617622195218641171605700291324893228507248559930579192517899275167208677386505912811317371399778642309573594407310688704721375437998252661319722214188251994674360264950082874192246603776

# %% [markdown]
# ## Ponto Flutuante

# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %% [markdown]
# ### Inf

# %%
10.0^309
# Out:
# Inf

# %%
1 / Inf
# Out:
# 0.0

# %%
-1 / Inf
# Out:
# -0.0

# %%
1 / -Inf
# Out:
# -0.0

# %%
Inf - Inf  # Not-a-Number
# Out:
# NaN

# %%
Inf / Inf
# Out:
# NaN

# %%
0 / 0
# Out:
# NaN

# %% [markdown]
# O "zero" pode ser encontrado de diversas formas, por exemplo:

# %%
x = 1.0
while x > 0
    println("x = $x")
    x = x / 2
end
println("x = $x")
# Out:
# x = 1.0
# x = 0.5
# x = 0.25
# x = 0.125
# x = 0.0625
# x = 0.03125
# x = 0.015625
# x = 0.0078125
# x = 0.00390625
# x = 0.001953125
# x = 0.0009765625
# x = 0.00048828125
# x = 0.000244140625
# x = 0.0001220703125
# x = 6.103515625e-5
# x = 3.0517578125e-5
# x = 1.52587890625e-5
# x = 7.62939453125e-6
# x = 3.814697265625e-6
# x = 1.9073486328125e-6
# x = 9.5367431640625e-7
# x = 4.76837158203125e-7
# x = 2.384185791015625e-7
# x = 1.1920928955078125e-7
# x = 5.960464477539063e-8
# x = 2.9802322387695312e-8
# x = 1.4901161193847656e-8
# x = 7.450580596923828e-9
# x = 3.725290298461914e-9
# x = 1.862645149230957e-9
# x = 9.313225746154785e-10
# x = 4.656612873077393e-10
# x = 2.3283064365386963e-10
# x = 1.1641532182693481e-10
# x = 5.820766091346741e-11
# x = 2.9103830456733704e-11
# x = 1.4551915228366852e-11
# x = 7.275957614183426e-12
# x = 3.637978807091713e-12
# x = 1.8189894035458565e-12
# x = 9.094947017729282e-13
# x = 4.547473508864641e-13
# x = 2.2737367544323206e-13
# ...
