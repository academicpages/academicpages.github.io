# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
#    "proceeding": {
#        "file" : "proceedings.bib",
#        "venuekey": "booktitle",
#        "venue-pretext": "",
#        "collection" : {"name":"talks",
#                        "permalink":"/talks/"}
#        
#    }
#    ,
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    
    bibdata = parser.parse_file(publist[pubsource]["file"])
    #print(bibdata)
    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""
            
            #print(bibdata.entries[bib_id])

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                #print(author)
                #print(author.first_names)
                #print(author.first_names[0])
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            if "address" in b.keys(): 
                citation + ", " + b["address"]
            citation = citation + ", " + pub_year + "."

            
            
            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 
            #md += "\ndate: " + str(pub_year) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            if "address" in b.keys(): 
                md += "\nlocation: '" + b["address"] + "'"
            
            #md += "\ntype: '" + 'Conference talk' + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"
            
            

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            #if url:
            #    md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            #else:
            #    md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)
            print(citation)
            print(md)

#            with open("../_publications/" + md_filename, 'w') as f:
            with open("../_talks/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
#  Xian Kong,  Paul Rudnicki,  Jian Qin, "Coarse-grained simulation of lithium dendrite suppression by flowable polymer coating." Presented at the American Physical Society March Meeting, 2019.
# ---
# title: "Coarse-grained simulation of lithium dendrite suppression by flowable polymer coating"
# collection: talks
# permalink: /talks/2019-01-01-Coarse-grained-simulation-of-lithium-dendrite-suppression-by-flowable-polymer-coating
# date: 2019-01-01
# venue: 'Presented at the American Physical Society March Meeting'
# location: 'Boston, MA'
# type: 'Conference talk'
# citation: ' Xian Kong,  Paul Rudnicki,  Jian Qin, &quot;Coarse-grained simulation of lithium dendrite suppression by flowable polymer coating.&quot; Presented at the American Physical Society March Meeting, 2019.'
# ---
# SUCESSFULLY PARSED kong2019coarse: " Coarse-grained simulation of lithium dendrite suppression by ... "
#  Xian Kong,  Jianwen Jiang, "Water Desalination Using Porous Organic Cage Membranes: A Simulation Exploration." Presented at the AIChE Annual Meeting, 2017.
# ---
# title: "Water Desalination Using Porous Organic Cage Membranes: A Simulation Exploration"
# collection: talks
# permalink: /talks/2017-01-01-Water-Desalination-Using-Porous-Organic-Cage-Membranes-A-Simulation-Exploration
# date: 2017-01-01
# venue: 'Presented at the AIChE Annual Meeting'
# location: 'Minneapolis, MN'
# type: 'Conference talk'
# citation: ' Xian Kong,  Jianwen Jiang, &quot;Water Desalination Using Porous Organic Cage Membranes: A Simulation Exploration.&quot; Presented at the AIChE Annual Meeting, 2017.'
# ---
# SUCESSFULLY PARSED kongPOCaiche: " Water Desalination Using Porous Organic Cage Membranes: A Si ... "
#  Xian Kong,  Jianwen Jiang, "Molecular Dynamics Simulation of Mixed Matrix Membrane Formed By Porous Organic Cage and Polymer with Intrinsic Microporosity." Presented at the AIChE Annual Meeting, 2017.
# ---
# title: "Molecular Dynamics Simulation of Mixed Matrix Membrane Formed By Porous Organic Cage and Polymer with Intrinsic Microporosity"
# collection: talks
# permalink: /talks/2017-01-01-Molecular-Dynamics-Simulation-of-Mixed-Matrix-Membrane-Formed-By-Porous-Organic-Cage-and-Polymer-with-Intrinsic-Microporosity
# date: 2017-01-01
# venue: 'Presented at the AIChE Annual Meeting'
# location: 'Minneapolis, MN'
# type: 'Conference talk'
# citation: ' Xian Kong,  Jianwen Jiang, &quot;Molecular Dynamics Simulation of Mixed Matrix Membrane Formed By Porous Organic Cage and Polymer with Intrinsic Microporosity.&quot; Presented at the AIChE Annual Meeting, 2017.'
# ---
# SUCESSFULLY PARSED kongMMMaiche: " Molecular Dynamics Simulation of Mixed Matrix Membrane Forme ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "A Theoretical Study on the Morphological Phase Diagram of Supported Lipid Bilayers." Presented at the American Physical Society March Meeting, 2017.
# ---
# title: "A Theoretical Study on the Morphological Phase Diagram of Supported Lipid Bilayers"
# collection: talks
# permalink: /talks/2017-01-01-A-Theoretical-Study-on-the-Morphological-Phase-Diagram-of-Supported-Lipid-Bilayers
# date: 2017-01-01
# venue: 'Presented at the American Physical Society March Meeting'
# location: 'New Orleans, LA'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, &quot;A Theoretical Study on the Morphological Phase Diagram of Supported Lipid Bilayers.&quot; Presented at the American Physical Society March Meeting, 2017.'
# ---
# SUCESSFULLY PARSED kong2017SLBaps: " A Theoretical Study on the Morphological Phase Diagram of Su ... "
#  Xian Kong,  Jianwen Jiang, "Water Desalination using Porous Organic Cage Membranes: A Simulation Exploration." Presented at 9th International Conference on Materials for Advanced Technologies, 2017.
# ---
# title: "Water Desalination using Porous Organic Cage Membranes: A Simulation Exploration"
# collection: talks
# permalink: /talks/2017-01-01-Water-Desalination-using-Porous-Organic-Cage-Membranes-A-Simulation-Exploration
# date: 2017-01-01
# venue: 'Presented at 9th International Conference on Materials for Advanced Technologies'
# location: 'Singapore, Singapore'
# type: 'Conference talk'
# citation: ' Xian Kong,  Jianwen Jiang, &quot;Water Desalination using Porous Organic Cage Membranes: A Simulation Exploration.&quot; Presented at 9th International Conference on Materials for Advanced Technologies, 2017.'
# ---
# SUCESSFULLY PARSED kong2017POCicmat: " Water Desalination using Porous Organic Cage Membranes: A Si ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "Pseudo Phase Diagrams of Supported Lipid Bilayers Formation: A Density Functional Theory Study." Presented at the AIChE Annual Meeting, 2015.
# ---
# title: "Pseudo Phase Diagrams of Supported Lipid Bilayers Formation: A Density Functional Theory Study"
# collection: talks
# permalink: /talks/2015-01-01-Pseudo-Phase-Diagrams-of-Supported-Lipid-Bilayers-Formation-A-Density-Functional-Theory-Study
# date: 2015-01-01
# venue: 'Presented at the AIChE Annual Meeting'
# location: 'Salt Lake City, UT'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, &quot;Pseudo Phase Diagrams of Supported Lipid Bilayers Formation: A Density Functional Theory Study.&quot; Presented at the AIChE Annual Meeting, 2015.'
# ---
# SUCESSFULLY PARSED kongSLBaiche: " Pseudo Phase Diagrams of Supported Lipid Bilayers Formation: ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu, "How Do Charge Density and Roughness of Surface Affect Formation of Supported Lipid Bilayers: A Coarse-Grained Molecular Dynamics Simulation." Presented at the AIChE Annual Meeting, 2013.
# ---
# title: "How Do Charge Density and Roughness of Surface Affect Formation of Supported Lipid Bilayers: A Coarse-Grained Molecular Dynamics Simulation"
# collection: talks
# permalink: /talks/2013-01-01-How-Do-Charge-Density-and-Roughness-of-Surface-Affect-Formation-of-Supported-Lipid-Bilayers-A-Coarse-Grained-Molecular-Dynamics-Simulation
# date: 2013-01-01
# venue: 'Presented at the AIChE Annual Meeting'
# location: 'San Francisco, CA'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu, &quot;How Do Charge Density and Roughness of Surface Affect Formation of Supported Lipid Bilayers: A Coarse-Grained Molecular Dynamics Simulation.&quot; Presented at the AIChE Annual Meeting, 2013.'
# ---
# SUCESSFULLY PARSED kongSLBaiche2013: " How Do Charge Density and Roughness of Surface Affect Format ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu, "表面张力影响磷脂双层膜稳定性的分子模拟研究." Presented at the 中国化工学会年会, 2015.
# ---
# title: "表面张力影响磷脂双层膜稳定性的分子模拟研究"
# collection: talks
# permalink: /talks/2015-01-01-
# date: 2015-01-01
# venue: 'Presented at the 中国化工学会年会'
# location: 'Beijing, China'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu, &quot;表面张力影响磷脂双层膜稳定性的分子模拟研究.&quot; Presented at the 中国化工学会年会, 2015.'
# ---
# SUCESSFULLY PARSED kongCICHE2015: " 表面张力影响磷脂双层膜稳定性的分子模拟研究  "
#  Xian Kong,  Diannan Lu, "Accelerating water transport through a charged SWCNT: A molecular dynamics simulation." Presented at the International Conference on Separation Science and Technology, 2013.
# ---
# title: "Accelerating water transport through a charged SWCNT: A molecular dynamics simulation"
# collection: talks
# permalink: /talks/2013-01-01-Accelerating-water-transport-through-a-charged-SWCNT-A-molecular-dynamics-simulation
# date: 2013-01-01
# venue: 'Presented at the International Conference on Separation Science and Technology'
# location: 'Chengdu, China'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu, &quot;Accelerating water transport through a charged SWCNT: A molecular dynamics simulation.&quot; Presented at the International Conference on Separation Science and Technology, 2013.'
# ---
# SUCESSFULLY PARSED kongCNT2013: " Accelerating water transport through a charged SWCNT: A mole ... "
#  Qile Chen,  Xian Kong*,  Diannan Lu,  Zheng Liu, "Acceleration of water transport in charged double-wall carbon nanotube." Presented at the Aseanian Membrane Society 8th, 2013.
# ---
# title: "Acceleration of water transport in charged double-wall carbon nanotube"
# collection: talks
# permalink: /talks/2013-01-01-Acceleration-of-water-transport-in-charged-double-wall-carbon-nanotube
# date: 2013-01-01
# venue: 'Presented at the Aseanian Membrane Society 8th'
# location: 'Xian, China'
# type: 'Conference talk'
# citation: ' Qile Chen,  Xian Kong*,  Diannan Lu,  Zheng Liu, &quot;Acceleration of water transport in charged double-wall carbon nanotube.&quot; Presented at the Aseanian Membrane Society 8th, 2013.'
# ---
# SUCESSFULLY PARSED kongXian2013: " Acceleration of water transport in charged double-wall carbo ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu, "How surface tension influences the properties of DPPC bilayer and its implication on hydrophobic drug delivery: A coarse grained MD simulation." Presented at the Biochemical and Molecular Engineering XVIII, 2013.
# ---
# title: "How surface tension influences the properties of DPPC bilayer and its implication on hydrophobic drug delivery: A coarse grained MD simulation"
# collection: talks
# permalink: /talks/2013-01-01-How-surface-tension-influences-the-properties-of-DPPC-bilayer-and-its-implication-on-hydrophobic-drug-delivery-A-coarse-grained-MD-simulation
# date: 2013-01-01
# venue: 'Presented at the Biochemical and Molecular Engineering XVIII'
# location: 'Beijing, China'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu, &quot;How surface tension influences the properties of DPPC bilayer and its implication on hydrophobic drug delivery: A coarse grained MD simulation.&quot; Presented at the Biochemical and Molecular Engineering XVIII, 2013.'
# ---
# SUCESSFULLY PARSED kongBJ2013: " How surface tension influences the properties of DPPC bilaye ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu, "Preparation and characterization of penicillin acylase nanogel." Presented at the Asian Congress on Biotechnology 2011, 2011.
# ---
# title: "Preparation and characterization of penicillin acylase nanogel"
# collection: talks
# permalink: /talks/2011-01-01-Preparation-and-characterization-of-penicillin-acylase-nanogel
# date: 2011-01-01
# venue: 'Presented at the Asian Congress on Biotechnology 2011'
# location: 'Shanghai, China'
# type: 'Conference talk'
# citation: ' Xian Kong,  Diannan Lu,  Zheng Liu, &quot;Preparation and characterization of penicillin acylase nanogel.&quot; Presented at the Asian Congress on Biotechnology 2011, 2011.'
# ---
# SUCESSFULLY PARSED kongACB2011: " Preparation and characterization of penicillin acylase nanog ... "
#  Jie Liu,  Xian Kong,  Jianwen Jiang, "Effects of Pore Size in Polybenzimidazole Membranes on the Performance of Organic Solvent Nanofiltration." Presented at the AIChE Annual Meeting, 2017.
# ---
# title: "Effects of Pore Size in Polybenzimidazole Membranes on the Performance of Organic Solvent Nanofiltration"
# collection: talks
# permalink: /talks/2017-01-01-Effects-of-Pore-Size-in-Polybenzimidazole-Membranes-on-the-Performance-of-Organic-Solvent-Nanofiltration
# date: 2017-01-01
# venue: 'Presented at the AIChE Annual Meeting'
# location: 'Minneapolis, MN'
# type: 'Conference talk'
# citation: ' Jie Liu,  Xian Kong,  Jianwen Jiang, &quot;Effects of Pore Size in Polybenzimidazole Membranes on the Performance of Organic Solvent Nanofiltration.&quot; Presented at the AIChE Annual Meeting, 2017.'
# ---
# SUCESSFULLY PARSED liuOSNaiche: " Effects of Pore Size in Polybenzimidazole Membranes on the P ... "
#  Margarita Khariton,  Xian Kong,  Jian Qin,  Bo Wang, "A Neuronal Jam in a Primitive Brain." Presented at the American Physical Society March Meeting, 2018.
# ---
# title: "A Neuronal Jam in a Primitive Brain"
# collection: talks
# permalink: /talks/2018-01-01-A-Neuronal-Jam-in-a-Primitive-Brain
# date: 2018-01-01
# venue: 'Presented at the American Physical Society March Meeting'
# location: 'Los Angeles, CA'
# type: 'Conference talk'
# citation: ' Margarita Khariton,  Xian Kong,  Jian Qin,  Bo Wang, &quot;A Neuronal Jam in a Primitive Brain.&quot; Presented at the American Physical Society March Meeting, 2018.'
# ---
# SUCESSFULLY PARSED khariton2018neuronal: " A Neuronal Jam in a Primitive Brain  "
