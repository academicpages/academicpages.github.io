# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
#    "proceeding": {
#        "file" : "proceedings.bib",
#        "venuekey": "booktitle",
#        "venue-pretext": "",
#        "collection" : {"name":"talks",
#                        "permalink":"/talks/"}
#        
#    }
#    ,
    "journal":{
        "file": "pubs.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    
    bibdata = parser.parse_file(publist[pubsource]["file"])
    #print(bibdata)
    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""
            
            #print(bibdata.entries[bib_id])

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                #print(author)
                #print(author.first_names)
                #print(author.first_names[0])
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " <i>" + html_escape(venue)
#            if "address" in b.keys(): 
#                citation + ", " + b["address"]
            citation = citation + "</i>, " + b["volume"] + "(" + b["number"] + ")"
            citation = citation + ":" + b["pages"]
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 
            #md += "\ndate: " + str(pub_year) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            if "address" in b.keys(): 
                md += "\nlocation: '" + b["address"] + "'"
            
            #md += "\ntype: '" + 'Conference talk' + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"
            
            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            #if url:
            #    md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            #else:
            #    md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)
            print(citation)
            #print(md)

            with open("../_publications/" + md_filename, 'w') as f:
#            with open("../_talks/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
#  Xian Kong,  Paul Rudnicki,  Snehashis Choudhury,  Zhenan Bao,  Jian Qin, "Dendrite suppression by a polymer coating: a coarse-grained molecular study." <i>Advanced Functional Materials</i>, accepted():, 2020.
# SUCESSFULLY PARSED kong2020Dendrite: " Dendrite suppression by a polymer coating: a coarse-grained  ... "
#  Meijuan Jia,  Xian Kong,  Lili Wang,  Yanbing Zhang,  Di Quan,  Liping Ding,  Diannan Lu,  Lei Jiang,  Wei Guo, "Light-Powered Directional Nanofluidic Ion Transport in Kirigami-Made Asymmetric Photonic-Ionic Devices." <i>Small</i>, 16(1):1905557, 2020.
# SUCESSFULLY PARSED jia2020light: " Light-Powered Directional Nanofluidic Ion Transport in Kirig ... "
#  Yaping Feng,  Haoyu Dai,  Jianjun Chen,  Xian Kong,  Jinlei Yang,  Lei Jiang, "Geometric structure-guided photo-driven ion current through asymmetric graphene oxide membranes." <i>Journal of Materials Chemistry A</i>, 7(35):20182-20186, 2019.
# SUCESSFULLY PARSED feng2019geometric: " Geometric structure-guided photo-driven ion current through  ... "
#  Yanbing Zhang*,  Fengyu Li*,  Xian Kong*,  Tangyue Xue,  Dan Liu,  Pan Jia,  Lili Wang,  Liping Ding,  Huanli Dong,  Diannan Lu,  Lei Jiang,  Wei Guo, "Photoinduced Directional Proton Transport through Printed Asymmetric Graphene Oxide Superstructures: A New Driving Mechanism under Full-Area Light Illumination." <i>Advanced Functional Materials</i>, 30(4):1907549, 2019.
# SUCESSFULLY PARSED zhang2019Photoinduced: " Photoinduced Directional Proton Transport through Printed As ... "
#  Xian Kong,  Jie Liu, "An Atomistic Simulation Study on POC/PIM Mixed-Matrix Membranes for Gas Separation." <i>The Journal of Physical Chemistry C</i>, 123(24):15113-15121, 2019.
# SUCESSFULLY PARSED kong2019POCMMM: " An Atomistic Simulation Study on POC/PIM Mixed-Matrix Membra ... "
#  Margarita Khariton*,  Xian Kong*,  Jian Qin,  Bo Wang, "Chromatic Neuronal Jamming in a Primitive Brain." <i>Nature Physics</i>, acceped():, 2020.
# SUCESSFULLY PARSED khariton2018chromatic: " Chromatic Neuronal Jamming in a Primitive Brain  "
#  Jinlei Yang*,  Xiaoyu Hu*,  Xian Kong*,  Pan Jia,  Danyan Ji,  Di Quan,  Lili Wang,  Qi Wen,  Diannan Lu,  Jianzhong Wu,  Lei Jiang,  Wei Guo, "Photo-induced ultrafast active ion transport through graphene oxide membranes." <i>Nature Communications</i>, 10(1):1171, 2019.
# SUCESSFULLY PARSED yang2019photo: " Photo-induced ultrafast active ion transport through graphen ... "
#  Xian Kong,  Diannan Lu,  Jianzhong Wu,  Zheng Liu, "A theoretical study on the morphological phase diagram of supported lipid bilayers." <i>Physical Chemistry Chemical Physics</i>, 19(25):16897-16903, 2017.
# SUCESSFULLY PARSED kong2017theoretical: " A theoretical study on the morphological phase diagram of su ... "
#  Xian Kong,  Jianwen Jiang, "Porous organic cage membranes for water desalination: a simulation exploration." <i>Physical Chemistry Chemical Physics</i>, 19(28):18178-18185, 2017.
# SUCESSFULLY PARSED kong2017porous: " Porous organic cage membranes for water desalination: a simu ... "
#  Xian Kong,  Zeyu Zhao,  Jianwen Jiang, "Dipeptides Embedded in a Lipid Bilayer Membrane as Synthetic Water Channels." <i>Langmuir</i>, 33(42):11490-11495, 2017.
# SUCESSFULLY PARSED kong2017dipeptides: " Dipeptides Embedded in a Lipid Bilayer Membrane as Synthetic ... "
#  Xian Kong,  Jianwen Jiang, "Amorphous porous organic cage membranes for water desalination." <i>The Journal of Physical Chemistry C</i>, 122(3):1732-1740, 2018.
# SUCESSFULLY PARSED kong2018amorphous: " Amorphous porous organic cage membranes for water desalinati ... "
#  Xian Kong,  Diannan Lu,  Jianzhong Wu,  Zheng Liu, "Spreading of a unilamellar liposome on charged substrates: A coarse-grained molecular simulation." <i>Langmuir</i>, 32(15):3785-3793, 2016.
# SUCESSFULLY PARSED kong2016spreading: " Spreading of a unilamellar liposome on charged substrates: A ... "
#  Xian Kong,  Alejandro Gallegos,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "A molecular theory for optimal blue energy extraction by electrical double layer expansion." <i>Physical Chemistry Chemical Physics</i>, 17(37):23970-23976, 2015.
# SUCESSFULLY PARSED kong2015BlueEnergy: " A molecular theory for optimal blue energy extraction by ele ... "
#  Xian Kong,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "Molecular dynamics for the charging behavior of nanostructured electric double layer capacitors containing room temperature ionic liquids." <i>Nano Research</i>, 8(3):931-940, 2015.
# SUCESSFULLY PARSED kong2015Capacitor: " Molecular dynamics for the charging behavior of nanostructur ... "
#  Xian Kong,  Jianzhong Wu,  Douglas Henderson, "Density functional theory study of the capacitance of single file ions in a narrow cylinder." <i>Journal of Colloid and Interface Science</i>, 449():130-135, 2015.
# SUCESSFULLY PARSED kong2015density: " Density functional theory study of the capacitance of single ... "
#  Xian Kong,  Jian Jiang,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "Molecular theory for electrokinetic transport in pH-regulated nanochannels." <i>The Journal of Physical Chemistry Letters</i>, 5(17):3015-3020, 2014.
# SUCESSFULLY PARSED kong2014molecular: " Molecular theory for electrokinetic transport in pH-regulate ... "
#  Xian Kong,  Shanshan Qin,  Diannan Lu,  Zheng Liu, "Surface tension effects on the phase transition of a DPPC bilayer with and without protein: a molecular dynamics simulation." <i>Physical Chemistry Chemical Physics</i>, 16(18):8434-8440, 2014.
# SUCESSFULLY PARSED kong2014surface: " Surface tension effects on the phase transition of a DPPC bi ... "
#  Xian Kong,  Zhixian Li,  Diannan Lu,  Zheng Liu,  Jianzhong Wu, "Multiscale simulation of surfactant-aquaporin complex formation and water permeability." <i>RSC Advances</i>, 4(71):37592-37599, 2014.
# SUCESSFULLY PARSED kong2014multiscale: " Multiscale simulation of surfactant-aquaporin complex format ... "
#  Xian Kong,  Xiaoyu Hu,  Diannan Lu,  Liu Zheng, "Molecular dynamics simulation of rupture of lipid bilayer under dynamic surface tension." <i>CIESC Journal</i>, 67(2):641, 2016.
# SUCESSFULLY PARSED kong2016bilayerrupture: " Molecular dynamics simulation of rupture of lipid bilayer un ... "
#  Xian Kong,  Changyuan Li,  Diannan Lu,  Qiang Li,  Zheng Liu, "Preparation and characterization of penicillin acylase nanogel." <i>CIESC Journal</i>, 6(62):1641-1648, 2011.
# SUCESSFULLY PARSED kong2011preparation: " Preparation and characterization of penicillin acylase nanog ... "
#  David Boyle,  Xian Kong,  Allen Pei,  Paul Rudnicki,  Feifei Shi,  William Huang,  Zhenan Bao,  Jian Qin,  Yi Cui, "Transient Voltammetry with Ultramicroelectrodes Reveals the Electron Transfer Kinetics of Lithium Metal Anodes." <i>ACS Energy Letters</i>, ():, 2020.
# SUCESSFULLY PARSED boyle2020transient: " Transient Voltammetry with Ultramicroelectrodes Reveals the  ... "
#  Ankun Yang,  Guangmin Zhou,  Xian Kong,  Rafael Vil{\'a},  Allen Pei,  Yecun Wu,  Xiaoyun Yu,  Xueli Zheng,  Chun-Lan Wu,  Bofei Liu,  Hao Chen,  Yan Xu,  Di Chen,  Yanxi Li,  Sirine Fakra,  Harold Hwang,  Jian Qin,  Steven Chu,  Yi Cui, "Electrochemical generation of liquid and solid sulfur on two-dimensional layered materials with distinct areal capacities." <i>Nature Nanotechnology</i>, ():1-7, 2020.
# SUCESSFULLY PARSED yang2020electrochemical: " Electrochemical generation of liquid and solid sulfur on two ... "
#  Chibueze Amanchukwu,  Xian Kong,  Jian Qin,  Yi Cui,  Zhenan Bao, "Nonpolar Alkanes Modify Lithium-Ion Solvation for Improved Lithium Deposition and Stripping." <i>Advanced Energy Materials</i>, ():1902116, 2019.
# SUCESSFULLY PARSED amanchukwu2019nonpolar: " Nonpolar Alkanes Modify Lithium-Ion Solvation for Improved L ... "
#  Jiayu Wan,  Jin Xie,  Xian Kong,  Zhe Liu,  Kai Liu,  Feifei Shi,  Allen Pei,  Hao Chen,  Wei Chen,  Jun Chen,  Xiaokun Zhang,  Linqi Zong,  Jiangyan Wang,  Long-Qing Chen,  Jian Qin,  Yi Cui, "Ultrathin, flexible, solid polymer composite electrolyte enabled with aligned nanoporous host for lithium batteries." <i>Nature Nanotechnology</i>, 14():705–711, 2019.
# SUCESSFULLY PARSED wan2019peo: " Ultrathin, flexible, solid polymer composite electrolyte ena ... "
#  Qile Chen,  Xian Kong,  Jipeng Li,  Diannan Lu,  Zheng Liu, "Electrokinetic desalination using honeycomb carbon nanotubes (HC-CNTs): a conceptual study by molecular simulation." <i>Physical Chemistry Chemical Physics</i>, 16(35):18941-18948, 2014.
# SUCESSFULLY PARSED chen2014electrokinetic: " Electrokinetic desalination using honeycomb carbon nanotubes ... "
#  Yijie Dong,  Zhe Lang,  Xian Kong,  Diannan Lu,  Zheng Liu, "Kinetic and multidimensional profiling of accelerated degradation of oil sludge by biostimulation." <i>Environmental Science: Processes &amp; Impacts</i>, 17(4):763-774, 2015.
# SUCESSFULLY PARSED dong2015kinetic: " Kinetic and multidimensional profiling of accelerated degrad ... "
#  Gong Chen,  Xian Kong,  Jingying Zhu,  Diannan Lu,  Zheng Liu, "How ABA block polymers activate cytochrome c in toluene: molecular dynamics simulation and experimental observation." <i>Physical Chemistry Chemical Physics</i>, 17(16):10708-10714, 2015.
# SUCESSFULLY PARSED chen2015aba: " How ABA block polymers activate cytochrome c in toluene: mol ... "
#  Jipeng Li,  Yiyun Ouyang,  Xian Kong,  Jingying Zhu,  Diannan Lu,  Zheng Liu, "A multi-scale molecular dynamics simulation of PMAL facilitated delivery of siRNA." <i>RSC Advances</i>, 5(83):68227-68233, 2015.
# SUCESSFULLY PARSED li2015multi: " A multi-scale molecular dynamics simulation of PMAL facilita ... "
#  Jipeng Li,  Xian Kong,  Diannan Lu,  Zheng Liu, "Italicized carbon nanotube facilitating water transport: a molecular dynamics simulation." <i>Science bulletin</i>, 60(18):1580-1586, 2015.
# SUCESSFULLY PARSED li2015italicized: " Italicized carbon nanotube facilitating water transport: a m ... "
# WARNING Missing Expected Field 'journal' from entry 陈其乐2014外壁荷电性质对双壁碳纳米管中水分子运动行为的影响: " 外壁荷电性质对双壁碳纳米管中水分子运动行为的影响  "
#  宪 孔,  畅原 李,  滇楠 卢,  强 李,  铮 刘, "青霉素酰化酶纳米凝胶的制备与性质." <i>化工学报</i>, 62(6):1641-1648, 2011.
# SUCESSFULLY PARSED 孔宪2011青霉素酰化酶纳米凝胶的制备与性质: " 青霉素酰化酶纳米凝胶的制备与性质  "
#  宪 孔,  晓宇 胡,  滇楠 卢,  铮 刘, "动态表面张力破裂磷脂膜的分子动力学模拟." <i>化工学报</i>, 67(2):641-647, 2015.
# SUCESSFULLY PARSED 孔宪2015动态表面张力破裂磷脂膜的分子动力学模拟: " 动态表面张力破裂磷脂膜的分子动力学模拟  "
#  Cheng Lian,  Xian Kong,  Honglai Liu,  Jianzhong Wu, "On the hydrophilicity of electrodes for capacitive energy extraction." <i>Journal of Physics: Condensed Matter</i>, 28(46):464008, 2016.
# SUCESSFULLY PARSED lian2016hydrophilicity: " On the hydrophilicity of electrodes for capacitive energy ex ... "
#  Gong Chen,  Xian Kong,  Diannan Lu,  Jianzhong Wu,  Zheng Liu, "Kinetics of CO 2 diffusion in human carbonic anhydrase: a study using molecular dynamics simulations and the Markov-state model." <i>Physical Chemistry Chemical Physics</i>, 19(18):11690-11697, 2017.
# SUCESSFULLY PARSED chen2017kinetics: " Kinetics of CO 2 diffusion in human carbonic anhydrase: a st ... "
#  Xiaoyu Hu,  Xian Kong,  Diannan Lu,  Jianzhong Wu, "A molecular theory for predicting the thermodynamic efficiency of electrokinetic energy conversion in slit nanochannels." <i>The Journal of Chemical Physics</i>, 148(8):084701, 2018.
# SUCESSFULLY PARSED hu2018molecular: " A molecular theory for predicting the thermodynamic efficien ... "
#  Jie Liu,  Xian Kong,  Jianwen Jiang, "Solvent nanofiltration through polybenzimidazole membranes: Unravelling the role of pore size from molecular simulations." <i>Journal of Membrane Science</i>, 564():782-787, 2018.
# SUCESSFULLY PARSED liu2018solvent: " Solvent nanofiltration through polybenzimidazole membranes:  ... "
