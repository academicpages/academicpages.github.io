# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "proceedings.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    }
#    ,
#    "journal":{
#        "file": "pubs.bib",
#        "venuekey" : "journal",
#        "venue-pretext" : "",
#        "collection" : {"name":"publications",
#                        "permalink":"/publication/"}
#    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""
            
            print(bibdata.entries[bib_id])

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                print(author)
                print(author.first_names)
                print(author.first_names[0])
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# Entry('article', fields=[('title', 'Dendrite suppression by a polymer coating: a coarse-grained molecular study'), ('journal', 'Advanced Functional Materials'), ('volume', 'accepted'), ('number', ''), ('pages', ''), ('year', '2020'), ('keywords', ''), ('doi', ''), ('url', 'https://onlinelibrary.wiley.com/doi/abs/10.1002/adfm.201907549')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Rudnicki, Paul E.'), Person('Choudhury, Snehashis'), Person('Bao, Zhenan'), Person('Qin, Jian')])]))
# Kong, Xian
# ['Xian']
# Xian
# Rudnicki, Paul E.
# ['Paul']
# Paul
# Choudhury, Snehashis
# ['Snehashis']
# Snehashis
# Bao, Zhenan
# ['Zhenan']
# Zhenan
# Qin, Jian
# ['Jian']
# Jian
# SUCESSFULLY PARSED kong2020Dendrite: " Dendrite suppression by a polymer coating: a coarse-grained  ... "
# Entry('article', fields=[('title', 'Light-Powered Directional Nanofluidic Ion Transport in Kirigami-Made Asymmetric Photonic-Ionic Devices'), ('journal', 'Small'), ('volume', '16'), ('number', '1'), ('pages', '1905557'), ('year', '2020'), ('publisher', 'Wiley Online Library')], persons=OrderedCaseInsensitiveDict([('author', [Person('Jia, Meijuan'), Person('Kong, Xian'), Person('Wang, Lili'), Person('Zhang, Yanbing'), Person('Quan, Di'), Person('Ding, Liping'), Person('Lu, Diannan'), Person('Jiang, Lei'), Person('Guo, Wei')])]))
# Jia, Meijuan
# ['Meijuan']
# Meijuan
# Kong, Xian
# ['Xian']
# Xian
# Wang, Lili
# ['Lili']
# Lili
# Zhang, Yanbing
# ['Yanbing']
# Yanbing
# Quan, Di
# ['Di']
# Di
# Ding, Liping
# ['Liping']
# Liping
# Lu, Diannan
# ['Diannan']
# Diannan
# Jiang, Lei
# ['Lei']
# Lei
# Guo, Wei
# ['Wei']
# Wei
# SUCESSFULLY PARSED jia2020light: " Light-Powered Directional Nanofluidic Ion Transport in Kirig ... "
# Entry('article', fields=[('title', 'Geometric structure-guided photo-driven ion current through asymmetric graphene oxide membranes'), ('journal', 'Journal of Materials Chemistry A'), ('volume', '7'), ('number', '35'), ('pages', '20182--20186'), ('year', '2019'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Feng, Yaping'), Person('Dai, Haoyu'), Person('Chen, Jianjun'), Person('Kong, Xian'), Person('Yang, Jinlei'), Person('Jiang, Lei')])]))
# Feng, Yaping
# ['Yaping']
# Yaping
# Dai, Haoyu
# ['Haoyu']
# Haoyu
# Chen, Jianjun
# ['Jianjun']
# Jianjun
# Kong, Xian
# ['Xian']
# Xian
# Yang, Jinlei
# ['Jinlei']
# Jinlei
# Jiang, Lei
# ['Lei']
# Lei
# SUCESSFULLY PARSED feng2019geometric: " Geometric structure-guided photo-driven ion current through  ... "
# WARNING Missing Expected Field 'year' from entry zhang2019Photoinduced: " Photoinduced Directional Proto ... "
# Entry('article', fields=[('title', 'An Atomistic Simulation Study on POC/PIM Mixed-Matrix Membranes for Gas Separation'), ('journal', 'The Journal of Physical Chemistry C'), ('volume', '123'), ('number', '24'), ('pages', '15113-15121'), ('year', '2019'), ('publisher', 'American Chemical Society')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Liu, Jie')])]))
# Kong, Xian
# ['Xian']
# Xian
# Liu, Jie
# ['Jie']
# Jie
# SUCESSFULLY PARSED kong2019POCMMM: " An Atomistic Simulation Study on POC/PIM Mixed-Matrix Membra ... "
# Entry('article', fields=[('title', 'Chromatic Neuronal Jamming in a Primitive Brain'), ('journal', 'Nature Physics'), ('volume', 'acceped'), ('number', ''), ('pages', ''), ('year', '2020'), ('publisher', '')], persons=OrderedCaseInsensitiveDict([('author', [Person('Khariton*, Margarita'), Person('Kong*, Xian'), Person('Qin, Jian'), Person('Wang, Bo')])]))
# Khariton*, Margarita
# ['Margarita']
# Margarita
# Kong*, Xian
# ['Xian']
# Xian
# Qin, Jian
# ['Jian']
# Jian
# Wang, Bo
# ['Bo']
# Bo
# SUCESSFULLY PARSED khariton2018chromatic: " Chromatic Neuronal Jamming in a Primitive Brain  "
# Entry('article', fields=[('title', 'Photo-induced ultrafast active ion transport through graphene oxide membranes'), ('journal', 'Nature Communications'), ('volume', '10'), ('number', '1'), ('pages', '1171'), ('year', '2019'), ('publisher', 'Nature Publishing Group')], persons=OrderedCaseInsensitiveDict([('author', [Person('Yang*, Jinlei'), Person('Hu*, Xiaoyu'), Person('Kong*, Xian'), Person('Jia, Pan'), Person('Ji, Danyan'), Person('Quan, Di'), Person('Wang, Lili'), Person('Wen, Qi'), Person('Lu, Diannan'), Person('Wu, Jianzhong'), Person('Jiang, Lei'), Person('Guo, Wei')])]))
# Yang*, Jinlei
# ['Jinlei']
# Jinlei
# Hu*, Xiaoyu
# ['Xiaoyu']
# Xiaoyu
# Kong*, Xian
# ['Xian']
# Xian
# Jia, Pan
# ['Pan']
# Pan
# Ji, Danyan
# ['Danyan']
# Danyan
# Quan, Di
# ['Di']
# Di
# Wang, Lili
# ['Lili']
# Lili
# Wen, Qi
# ['Qi']
# Qi
# Lu, Diannan
# ['Diannan']
# Diannan
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# Jiang, Lei
# ['Lei']
# Lei
# Guo, Wei
# ['Wei']
# Wei
# SUCESSFULLY PARSED yang2019photo: " Photo-induced ultrafast active ion transport through graphen ... "
# Entry('article', fields=[('title', 'A theoretical study on the morphological phase diagram of supported lipid bilayers'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '19'), ('number', '25'), ('pages', '16897--16903'), ('year', '2017'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Lu, Diannan'), Person('Wu, Jianzhong'), Person('Liu, Zheng')])]))
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED kong2017theoretical: " A theoretical study on the morphological phase diagram of su ... "
# Entry('article', fields=[('title', 'Porous organic cage membranes for water desalination: a simulation exploration'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '19'), ('number', '28'), ('pages', '18178--18185'), ('year', '2017'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Jiang, Jianwen')])]))
# Kong, Xian
# ['Xian']
# Xian
# Jiang, Jianwen
# ['Jianwen']
# Jianwen
# SUCESSFULLY PARSED kong2017porous: " Porous organic cage membranes for water desalination: a simu ... "
# Entry('article', fields=[('title', 'Dipeptides Embedded in a Lipid Bilayer Membrane as Synthetic Water Channels'), ('journal', 'Langmuir'), ('volume', '33'), ('number', '42'), ('pages', '11490--11495'), ('year', '2017'), ('publisher', 'American Chemical Society')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Zhao, Zeyu'), Person('Jiang, Jianwen')])]))
# Kong, Xian
# ['Xian']
# Xian
# Zhao, Zeyu
# ['Zeyu']
# Zeyu
# Jiang, Jianwen
# ['Jianwen']
# Jianwen
# SUCESSFULLY PARSED kong2017dipeptides: " Dipeptides Embedded in a Lipid Bilayer Membrane as Synthetic ... "
# Entry('article', fields=[('title', 'Amorphous porous organic cage membranes for water desalination'), ('journal', 'The Journal of Physical Chemistry C'), ('volume', '122'), ('number', '3'), ('pages', '1732--1740'), ('year', '2018'), ('publisher', 'American Chemical Society')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Jiang, Jianwen')])]))
# Kong, Xian
# ['Xian']
# Xian
# Jiang, Jianwen
# ['Jianwen']
# Jianwen
# SUCESSFULLY PARSED kong2018amorphous: " Amorphous porous organic cage membranes for water desalinati ... "
# Entry('article', fields=[('title', 'Spreading of a unilamellar liposome on charged substrates: A coarse-grained molecular simulation'), ('journal', 'Langmuir'), ('volume', '32'), ('number', '15'), ('pages', '3785--3793'), ('year', '2016'), ('publisher', 'American Chemical Society')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Lu, Diannan'), Person('Wu, Jianzhong'), Person('Liu, Zheng')])]))
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED kong2016spreading: " Spreading of a unilamellar liposome on charged substrates: A ... "
# Entry('article', fields=[('title', 'A molecular theory for optimal blue energy extraction by electrical double layer expansion'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '17'), ('number', '37'), ('pages', '23970--23976'), ('year', '2015'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Gallegos, Alejandro'), Person('Lu, Diannan'), Person('Liu, Zheng'), Person('Wu, Jianzhong')])]))
# Kong, Xian
# ['Xian']
# Xian
# Gallegos, Alejandro
# ['Alejandro']
# Alejandro
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED kong2015BlueEnergy: " A molecular theory for optimal blue energy extraction by ele ... "
# Entry('article', fields=[('title', 'Molecular dynamics for the charging behavior of nanostructured electric double layer capacitors containing room temperature ionic liquids'), ('journal', 'Nano Research'), ('volume', '8'), ('number', '3'), ('pages', '931--940'), ('year', '2015'), ('publisher', 'Tsinghua University Press')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Lu, Diannan'), Person('Liu, Zheng'), Person('Wu, Jianzhong')])]))
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED kong2015Capacitor: " Molecular dynamics for the charging behavior of nanostructur ... "
# Entry('article', fields=[('title', 'Density functional theory study of the capacitance of single file ions in a narrow cylinder'), ('journal', 'Journal of Colloid and Interface Science'), ('volume', '449'), ('pages', '130--135'), ('year', '2015'), ('publisher', 'Elsevier')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Wu, Jianzhong'), Person('Henderson, Douglas')])]))
# Kong, Xian
# ['Xian']
# Xian
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# Henderson, Douglas
# ['Douglas']
# Douglas
# SUCESSFULLY PARSED kong2015density: " Density functional theory study of the capacitance of single ... "
# Entry('article', fields=[('title', 'Molecular theory for electrokinetic transport in pH-regulated nanochannels'), ('journal', 'The Journal of Physical Chemistry Letters'), ('volume', '5'), ('number', '17'), ('pages', '3015--3020'), ('year', '2014'), ('publisher', 'American Chemical Society')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Jiang, Jian'), Person('Lu, Diannan'), Person('Liu, Zheng'), Person('Wu, Jianzhong')])]))
# Kong, Xian
# ['Xian']
# Xian
# Jiang, Jian
# ['Jian']
# Jian
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED kong2014molecular: " Molecular theory for electrokinetic transport in pH-regulate ... "
# Entry('article', fields=[('title', 'Surface tension effects on the phase transition of a DPPC bilayer with and without protein: a molecular dynamics simulation'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '16'), ('number', '18'), ('pages', '8434--8440'), ('year', '2014'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Qin, Shanshan'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Kong, Xian
# ['Xian']
# Xian
# Qin, Shanshan
# ['Shanshan']
# Shanshan
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED kong2014surface: " Surface tension effects on the phase transition of a DPPC bi ... "
# Entry('article', fields=[('title', 'Multiscale simulation of surfactant--aquaporin complex formation and water permeability'), ('journal', 'RSC Advances'), ('volume', '4'), ('number', '71'), ('pages', '37592--37599'), ('year', '2014'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Li, Zhixian'), Person('Lu, Diannan'), Person('Liu, Zheng'), Person('Wu, Jianzhong')])]))
# Kong, Xian
# ['Xian']
# Xian
# Li, Zhixian
# ['Zhixian']
# Zhixian
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED kong2014multiscale: " Multiscale simulation of surfactant--aquaporin complex forma ... "
# Entry('article', fields=[('title', 'Molecular dynamics simulation of rupture of lipid bilayer under dynamic surface tension'), ('publisher', 'CIESC Journal'), ('year', '2016'), ('journal', 'CIESC Journal'), ('volume', '67'), ('number', '2'), ('eid', '641'), ('numpages', '6'), ('pages', '641'), ('url', 'http://www.hgxb.com.cn/CN/abstract/article_17761.shtml'), ('doi', '10.11949/j.issn.0438-1157.20151147')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Hu, Xiaoyu'), Person('Lu, Diannan'), Person('Zheng, Liu')])]))
# Kong, Xian
# ['Xian']
# Xian
# Hu, Xiaoyu
# ['Xiaoyu']
# Xiaoyu
# Lu, Diannan
# ['Diannan']
# Diannan
# Zheng, Liu
# ['Liu']
# Liu
# SUCESSFULLY PARSED kong2016bilayerrupture: " Molecular dynamics simulation of rupture of lipid bilayer un ... "
# Entry('article', fields=[('title', 'Preparation and characterization of penicillin acylase nanogel'), ('journal', 'CIESC Journal'), ('volume', '6'), ('year', '2011')], persons=OrderedCaseInsensitiveDict([('author', [Person('Kong, Xian'), Person('Li, Changyuan'), Person('Lu, Diannan'), Person('Li, Qiang'), Person('Liu, Zheng')])]))
# Kong, Xian
# ['Xian']
# Xian
# Li, Changyuan
# ['Changyuan']
# Changyuan
# Lu, Diannan
# ['Diannan']
# Diannan
# Li, Qiang
# ['Qiang']
# Qiang
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED kong2011preparation: " Preparation and characterization of penicillin acylase nanog ... "
# Entry('article', fields=[('title', 'Transient Voltammetry with Ultramicroelectrodes Reveals the Electron Transfer Kinetics of Lithium Metal Anodes'), ('journal', 'ACS Energy Letters'), ('year', '2020'), ('publisher', 'ACS Publications')], persons=OrderedCaseInsensitiveDict([('author', [Person('Boyle, David T'), Person('Kong, Xian'), Person('Pei, Allen'), Person('Rudnicki, Paul E'), Person('Shi, Feifei'), Person('Huang, William'), Person('Bao, Zhenan'), Person('Qin, Jian'), Person('Cui, Yi')])]))
# Boyle, David T
# ['David']
# David
# Kong, Xian
# ['Xian']
# Xian
# Pei, Allen
# ['Allen']
# Allen
# Rudnicki, Paul E
# ['Paul']
# Paul
# Shi, Feifei
# ['Feifei']
# Feifei
# Huang, William
# ['William']
# William
# Bao, Zhenan
# ['Zhenan']
# Zhenan
# Qin, Jian
# ['Jian']
# Jian
# Cui, Yi
# ['Yi']
# Yi
# SUCESSFULLY PARSED boyle2020transient: " Transient Voltammetry with Ultramicroelectrodes Reveals the  ... "
# Entry('article', fields=[('title', 'Electrochemical generation of liquid and solid sulfur on two-dimensional layered materials with distinct areal capacities'), ('journal', 'Nature Nanotechnology'), ('pages', '1--7'), ('year', '2020'), ('publisher', 'Nature Publishing Group')], persons=OrderedCaseInsensitiveDict([('author', [Person('Yang, Ankun'), Person('Zhou, Guangmin'), Person('Kong, Xian'), Person("Vil{\\'a}, Rafael A"), Person('Pei, Allen'), Person('Wu, Yecun'), Person('Yu, Xiaoyun'), Person('Zheng, Xueli'), Person('Wu, Chun-Lan'), Person('Liu, Bofei'), Person('Chen, Hao'), Person('Xu, Yan'), Person('Chen, Di'), Person('Li, Yanxi'), Person('Fakra, Sirine'), Person('Hwang, Harold'), Person('Qin, Jian'), Person('Chu, Steven'), Person('Cui, Yi')])]))
# Yang, Ankun
# ['Ankun']
# Ankun
# Zhou, Guangmin
# ['Guangmin']
# Guangmin
# Kong, Xian
# ['Xian']
# Xian
# Vil{\'a}, Rafael A
# ['Rafael']
# Rafael
# Pei, Allen
# ['Allen']
# Allen
# Wu, Yecun
# ['Yecun']
# Yecun
# Yu, Xiaoyun
# ['Xiaoyun']
# Xiaoyun
# Zheng, Xueli
# ['Xueli']
# Xueli
# Wu, Chun-Lan
# ['Chun-Lan']
# Chun-Lan
# Liu, Bofei
# ['Bofei']
# Bofei
# Chen, Hao
# ['Hao']
# Hao
# Xu, Yan
# ['Yan']
# Yan
# Chen, Di
# ['Di']
# Di
# Li, Yanxi
# ['Yanxi']
# Yanxi
# Fakra, Sirine
# ['Sirine']
# Sirine
# Hwang, Harold
# ['Harold']
# Harold
# Qin, Jian
# ['Jian']
# Jian
# Chu, Steven
# ['Steven']
# Steven
# Cui, Yi
# ['Yi']
# Yi
# SUCESSFULLY PARSED yang2020electrochemical: " Electrochemical generation of liquid and solid sulfur on two ... "
# Entry('article', fields=[('title', 'Nonpolar Alkanes Modify Lithium-Ion Solvation for Improved Lithium Deposition and Stripping'), ('journal', 'Advanced Energy Materials'), ('pages', '1902116'), ('year', '2019'), ('publisher', 'Wiley Online Library')], persons=OrderedCaseInsensitiveDict([('author', [Person('Amanchukwu, Chibueze V'), Person('Kong, Xian'), Person('Qin, Jian'), Person('Cui, Yi'), Person('Bao, Zhenan')])]))
# Amanchukwu, Chibueze V
# ['Chibueze']
# Chibueze
# Kong, Xian
# ['Xian']
# Xian
# Qin, Jian
# ['Jian']
# Jian
# Cui, Yi
# ['Yi']
# Yi
# Bao, Zhenan
# ['Zhenan']
# Zhenan
# SUCESSFULLY PARSED amanchukwu2019nonpolar: " Nonpolar Alkanes Modify Lithium-Ion Solvation for Improved L ... "
# Entry('article', fields=[('title', 'Ultrathin, flexible, solid polymer composite electrolyte enabled with aligned nanoporous host for lithium batteries'), ('journal', 'Nature Nanotechnology'), ('volume', '14'), ('number', ''), ('pages', '705–711'), ('year', '2019'), ('publisher', 'Nature Publishing Group')], persons=OrderedCaseInsensitiveDict([('author', [Person('Wan, Jiayu'), Person('Xie, Jin'), Person('Kong, Xian'), Person('Liu, Zhe'), Person('Liu, Kai'), Person('Shi, Feifei'), Person('Pei, Allen'), Person('Chen, Hao'), Person('Chen, Wei'), Person('Chen, Jun'), Person('Zhang, Xiaokun'), Person('Zong, Linqi'), Person('Wang, Jiangyan'), Person('Chen, Long-Qing'), Person('Qin, Jian'), Person('Cui, Yi')])]))
# Wan, Jiayu
# ['Jiayu']
# Jiayu
# Xie, Jin
# ['Jin']
# Jin
# Kong, Xian
# ['Xian']
# Xian
# Liu, Zhe
# ['Zhe']
# Zhe
# Liu, Kai
# ['Kai']
# Kai
# Shi, Feifei
# ['Feifei']
# Feifei
# Pei, Allen
# ['Allen']
# Allen
# Chen, Hao
# ['Hao']
# Hao
# Chen, Wei
# ['Wei']
# Wei
# Chen, Jun
# ['Jun']
# Jun
# Zhang, Xiaokun
# ['Xiaokun']
# Xiaokun
# Zong, Linqi
# ['Linqi']
# Linqi
# Wang, Jiangyan
# ['Jiangyan']
# Jiangyan
# Chen, Long-Qing
# ['Long-Qing']
# Long-Qing
# Qin, Jian
# ['Jian']
# Jian
# Cui, Yi
# ['Yi']
# Yi
# SUCESSFULLY PARSED wan2019peo: " Ultrathin, flexible, solid polymer composite electrolyte ena ... "
# Entry('article', fields=[('title', 'Electrokinetic desalination using honeycomb carbon nanotubes (HC-CNTs): a conceptual study by molecular simulation'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '16'), ('number', '35'), ('pages', '18941--18948'), ('year', '2014'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Chen, Qile'), Person('Kong, Xian'), Person('Li, Jipeng'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Chen, Qile
# ['Qile']
# Qile
# Kong, Xian
# ['Xian']
# Xian
# Li, Jipeng
# ['Jipeng']
# Jipeng
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED chen2014electrokinetic: " Electrokinetic desalination using honeycomb carbon nanotubes ... "
# Entry('article', fields=[('title', 'Kinetic and multidimensional profiling of accelerated degradation of oil sludge by biostimulation'), ('journal', 'Environmental Science: Processes \\& Impacts'), ('volume', '17'), ('number', '4'), ('pages', '763--774'), ('year', '2015'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Dong, Yijie'), Person('Lang, Zhe'), Person('Kong, Xian'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Dong, Yijie
# ['Yijie']
# Yijie
# Lang, Zhe
# ['Zhe']
# Zhe
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED dong2015kinetic: " Kinetic and multidimensional profiling of accelerated degrad ... "
# Entry('article', fields=[('title', 'How ABA block polymers activate cytochrome c in toluene: molecular dynamics simulation and experimental observation'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '17'), ('number', '16'), ('pages', '10708--10714'), ('year', '2015'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Chen, Gong'), Person('Kong, Xian'), Person('Zhu, Jingying'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Chen, Gong
# ['Gong']
# Gong
# Kong, Xian
# ['Xian']
# Xian
# Zhu, Jingying
# ['Jingying']
# Jingying
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED chen2015aba: " How ABA block polymers activate cytochrome c in toluene: mol ... "
# Entry('article', fields=[('title', 'A multi-scale molecular dynamics simulation of PMAL facilitated delivery of siRNA'), ('journal', 'RSC Advances'), ('volume', '5'), ('number', '83'), ('pages', '68227--68233'), ('year', '2015'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Li, Jipeng'), Person('Ouyang, Yiyun'), Person('Kong, Xian'), Person('Zhu, Jingying'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Li, Jipeng
# ['Jipeng']
# Jipeng
# Ouyang, Yiyun
# ['Yiyun']
# Yiyun
# Kong, Xian
# ['Xian']
# Xian
# Zhu, Jingying
# ['Jingying']
# Jingying
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED li2015multi: " A multi-scale molecular dynamics simulation of PMAL facilita ... "
# Entry('article', fields=[('title', 'Italicized carbon nanotube facilitating water transport: a molecular dynamics simulation'), ('journal', 'Science bulletin'), ('volume', '60'), ('number', '18'), ('pages', '1580--1586'), ('year', '2015'), ('publisher', 'Science China Press')], persons=OrderedCaseInsensitiveDict([('author', [Person('Li, Jipeng'), Person('Kong, Xian'), Person('Lu, Diannan'), Person('Liu, Zheng')])]))
# Li, Jipeng
# ['Jipeng']
# Jipeng
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED li2015italicized: " Italicized carbon nanotube facilitating water transport: a m ... "
# Entry('phdthesis', fields=[('title', '外壁荷电性质对双壁碳纳米管中水分子运动行为的影响'), ('year', '2014')], persons=OrderedCaseInsensitiveDict([('author', [Person('陈, 其乐'), Person('孔, 宪'), Person('卢, 滇楠'), Person('刘, 铮')])]))
# 陈, 其乐
# ['其乐']
# 其乐
# 孔, 宪
# ['宪']
# 宪
# 卢, 滇楠
# ['滇楠']
# 滇楠
# 刘, 铮
# ['铮']
# 铮
# WARNING Missing Expected Field 'journal' from entry 陈其乐2014外壁荷电性质对双壁碳纳米管中水分子运动行为的影响: " 外壁荷电性质对双壁碳纳米管中水分子运动行为的影响  "
# Entry('article', fields=[('title', '< 青霉素酰化酶纳米凝胶的制备与性质'), ('journal', '化工学报'), ('volume', '62'), ('number', '6'), ('pages', '1641--1648'), ('year', '2011')], persons=OrderedCaseInsensitiveDict([('author', [Person('孔, 宪'), Person('李, 畅原'), Person('卢, 滇楠'), Person('李, 强'), Person('刘, 铮')])]))
# 孔, 宪
# ['宪']
# 宪
# 李, 畅原
# ['畅原']
# 畅原
# 卢, 滇楠
# ['滇楠']
# 滇楠
# 李, 强
# ['强']
# 强
# 刘, 铮
# ['铮']
# 铮
# SUCESSFULLY PARSED 孔宪2011青霉素酰化酶纳米凝胶的制备与性质: " < 青霉素酰化酶纳米凝胶的制备与性质  "
# Entry('article', fields=[('title', '动态表面张力破裂磷脂膜的分子动力学模拟'), ('journal', '化工学报'), ('volume', '67'), ('number', '2'), ('pages', '641--647'), ('year', '2015')], persons=OrderedCaseInsensitiveDict([('author', [Person('孔, 宪'), Person('胡, 晓宇'), Person('卢, 滇楠'), Person('刘, 铮')])]))
# 孔, 宪
# ['宪']
# 宪
# 胡, 晓宇
# ['晓宇']
# 晓宇
# 卢, 滇楠
# ['滇楠']
# 滇楠
# 刘, 铮
# ['铮']
# 铮
# SUCESSFULLY PARSED 孔宪2015动态表面张力破裂磷脂膜的分子动力学模拟: " 动态表面张力破裂磷脂膜的分子动力学模拟  "
# Entry('article', fields=[('title', 'On the hydrophilicity of electrodes for capacitive energy extraction'), ('journal', 'Journal of Physics: Condensed Matter'), ('volume', '28'), ('number', '46'), ('pages', '464008'), ('year', '2016'), ('publisher', 'IOP Publishing')], persons=OrderedCaseInsensitiveDict([('author', [Person('Lian, Cheng'), Person('Kong, Xian'), Person('Liu, Honglai'), Person('Wu, Jianzhong')])]))
# Lian, Cheng
# ['Cheng']
# Cheng
# Kong, Xian
# ['Xian']
# Xian
# Liu, Honglai
# ['Honglai']
# Honglai
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED lian2016hydrophilicity: " On the hydrophilicity of electrodes for capacitive energy ex ... "
# Entry('article', fields=[('title', 'Kinetics of CO 2 diffusion in human carbonic anhydrase: a study using molecular dynamics simulations and the Markov-state model'), ('journal', 'Physical Chemistry Chemical Physics'), ('volume', '19'), ('number', '18'), ('pages', '11690--11697'), ('year', '2017'), ('publisher', 'Royal Society of Chemistry')], persons=OrderedCaseInsensitiveDict([('author', [Person('Chen, Gong'), Person('Kong, Xian'), Person('Lu, Diannan'), Person('Wu, Jianzhong'), Person('Liu, Zheng')])]))
# Chen, Gong
# ['Gong']
# Gong
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# Liu, Zheng
# ['Zheng']
# Zheng
# SUCESSFULLY PARSED chen2017kinetics: " Kinetics of CO 2 diffusion in human carbonic anhydrase: a st ... "
# Entry('article', fields=[('title', 'A molecular theory for predicting the thermodynamic efficiency of electrokinetic energy conversion in slit nanochannels'), ('journal', 'The Journal of Chemical Physics'), ('volume', '148'), ('number', '8'), ('pages', '084701'), ('year', '2018'), ('publisher', 'AIP Publishing')], persons=OrderedCaseInsensitiveDict([('author', [Person('Hu, Xiaoyu'), Person('Kong, Xian'), Person('Lu, Diannan'), Person('Wu, Jianzhong')])]))
# Hu, Xiaoyu
# ['Xiaoyu']
# Xiaoyu
# Kong, Xian
# ['Xian']
# Xian
# Lu, Diannan
# ['Diannan']
# Diannan
# Wu, Jianzhong
# ['Jianzhong']
# Jianzhong
# SUCESSFULLY PARSED hu2018molecular: " A molecular theory for predicting the thermodynamic efficien ... "
# Entry('article', fields=[('title', 'Solvent nanofiltration through polybenzimidazole membranes: Unravelling the role of pore size from molecular simulations'), ('journal', 'Journal of Membrane Science'), ('volume', '564'), ('pages', '782--787'), ('year', '2018'), ('publisher', 'Elsevier')], persons=OrderedCaseInsensitiveDict([('author', [Person('Liu, Jie'), Person('Kong, Xian'), Person('Jiang, Jianwen')])]))
# Liu, Jie
# ['Jie']
# Jie
# Kong, Xian
# ['Xian']
# Xian
# Jiang, Jianwen
# ['Jianwen']
# Jianwen
# SUCESSFULLY PARSED liu2018solvent: " Solvent nanofiltration through polybenzimidazole membranes:  ... "
