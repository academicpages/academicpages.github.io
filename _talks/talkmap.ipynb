# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: getorg in /home/research/.local/lib/python3.8/site-packages (0.3.1)
# Requirement already satisfied: geopy in /home/research/.local/lib/python3.8/site-packages (from getorg) (2.2.0)
# Requirement already satisfied: pygithub in /home/research/.local/lib/python3.8/site-packages (from getorg) (1.55)
# Requirement already satisfied: retrying in /home/research/.local/lib/python3.8/site-packages (from getorg) (1.3.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/research/.local/lib/python3.8/site-packages (from geopy->getorg) (1.52)
# Requirement already satisfied: requests>=2.14.0 in /usr/lib/python3/dist-packages (from pygithub->getorg) (2.22.0)
# Requirement already satisfied: pyjwt>=2.0 in /home/research/.local/lib/python3.8/site-packages (from pygithub->getorg) (2.3.0)
# Requirement already satisfied: deprecated in /home/research/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.2.13)
# Requirement already satisfied: pynacl>=1.4.0 in /home/research/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: six>=1.7.0 in /home/research/.local/lib/python3.8/site-packages (from retrying->getorg) (1.15.0)
# Requirement already satisfied: cffi>=1.4.1 in /home/research/.local/lib/python3.8/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.15.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/research/.local/lib/python3.8/site-packages (from deprecated->pygithub->getorg) (1.12.1)
# Requirement already satisfied: pycparser in /home/research/.local/lib/python3.8/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# IPywidgets and ipyleaflet support enabled.

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent='iliasgiannako@gmail.com')
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# Utrecht, Netherlands
#  Utrecht, Nederland
# Online
#  Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# London, UK
#  London, Greater London, England, SW1A 2DX, United Kingdom
# Online
#  Online, Croix d'Argent, Montpellier, Hérault, Occitanie, France métropolitaine, France
# Lisbon, Portugal
#  Lisboa, 1100-148, Portugal
# Moscow, Russian Federation
#  Москва, Центральный федеральный округ, 103073, Россия
# New York, NY, USA
#  New York, United States

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
